# %% [markdown]
# # CALCULO DE VOLUMEN DE SHOTCRETE

# %% [markdown]
# **Shot Concrete:** Lanzar o Disparar concreto; Mortero o concreto proyectado neumáticamente a alta velocidad sobre una supericie.
#
# * Mezcla Humeda: Agregados, cemento, agua aditivos.

# %%
from IPython.display import Image
Image(filename="../Imagenes/ciclo_minado_shotcrete.jpg")

# %% [markdown]
# ## Cálculo del perímetro
#
# **P = 2H - r(4-Pi) + A**
#
# P = Perimetro(m)
#
# H = Altura(m)
#
# R = Radio(m)
#
# A = Ancho(m)

# %% [markdown]
# ##  FORMULA
#
# **V = (PxL) x %Rg x %Rb x %C x Cp x e**
#
# V = Volumen (m3)
#
# P = Perimtetro (m)
#
# L = Longitud (m)
#
# Rg = Rugosidad (%)
#
# Rb = Rebote (%)
#
# C = Cuba (%)
#
# Cp = Compactación (%)
#
# e = Espesor (m)

# %%
import numpy as np
H = int(input("Altura m: "))
R = int(input("Radio m: "))
A = int(input("Ancho m: "))
L = int(input("Longitud m: "))
Rg = int(input("Rugosidad %: "))
Rb = int(input("Rebote %: "))
C = int(input("Cuba %: "))
Cp = int(input("Compactación %: "))
e = int(input("Espesor m: "))

P = 2 * H - R * (4 - np.pi) + A
V = P * L * Rg * Rb * C * Cp * e / 1000000

print(f"El voluemn de ShotCrete lanzado será {V} m3")
# Out:
# Altura m: 4
# Radio m: 1
# Ancho m: 5
# Longitud m: 3
# Rugosidad %: 5
# Rebote %: 5
# Cuba %: 5
# Compactación %: 5
# Espesor m: 2
# El voluemn de ShotCrete lanzado será 0.045530972450961715 m3
